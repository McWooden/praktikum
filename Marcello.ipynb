# %%
"Hello world!" # Ini namanya string
'Hello world!'
1234567890 # Ini namanya integer (Angka)

# %%
print("Hello world!")
print(123)
# Out:
# '\nprint("Hello world!")\nprint(123)\n'

# %%
print(2+3)
print(2 - 3)
print(2*3)
print(12/4)
# Out:
# 5
# -1
# 6
# 3.0
